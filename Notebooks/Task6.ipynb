# %% [markdown]
# # **Data Preprocessing for Tableau**

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Parquet_to_CSV") \
    .getOrCreate()

# Load Parquet dataset
df = spark.read.parquet("nifty_10m_fixed.parquet")

# Save as a single CSV file
df.coalesce(1) \
  .write \
  .mode("overwrite") \
  .option("header", True) \
  .csv("nifty_10m_single_csv")

# %%
import shutil

shutil.make_archive(
    "nifty_10m_single_csv",
    "zip",
    "nifty_10m_single_csv"
)
# Out:
# '/content/nifty_10m_single_csv.zip'

# %% [markdown]
# # **Dashboard 1 - Data Quality & Pipeline Monitoring**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Dashboard 2 - Model Performance & Feature Importance**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Dashboard 3 - Business Insights**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Dashboard 4 - Scalability & Cost Analysis**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
